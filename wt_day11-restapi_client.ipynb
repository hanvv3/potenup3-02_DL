# %%
import requests

url = "http://localhost:8080/infer"

with open('./data/Celeb/test/뉴진스 해린/Image_98.png', 'rb') as f:
    response = requests.post(url, files={'file':f})
    
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'result': '장원영',
#  'index': 1,
#  'filename': 'ae021c93-6ccc-421a-a3b1-7c2f95d05e5b.png'}

# %%
## server stress test 해야함 - 툴을 GPT한테 만들어 달라고 물어보면 됨.
